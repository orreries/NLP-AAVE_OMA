# %% [markdown]
# # **Youtube Videos Transcription with OpenAI's Whisper**
#
# [![blog post shield](https://img.shields.io/static/v1?label=&message=Blog%20post&color=blue&style=for-the-badge&logo=openai&link=https://openai.com/blog/whisper)](https://openai.com/blog/whisper)
# [![notebook shield](https://img.shields.io/static/v1?label=&message=Notebook&color=blue&style=for-the-badge&logo=googlecolab&link=https://colab.research.google.com/github/ArthurFDLR/whisper-youtube/blob/main/whisper_youtube.ipynb)](https://colab.research.google.com/github/ArthurFDLR/whisper-youtube/blob/main/whisper_youtube.ipynb)
# [![repository shield](https://img.shields.io/static/v1?label=&message=Repository&color=blue&style=for-the-badge&logo=github&link=https://github.com/openai/whisper)](https://github.com/openai/whisper)
# [![paper shield](https://img.shields.io/static/v1?label=&message=Paper&color=blue&style=for-the-badge&link=https://cdn.openai.com/papers/whisper.pdf)](https://cdn.openai.com/papers/whisper.pdf)
# [![model card shield](https://img.shields.io/static/v1?label=&message=Model%20card&color=blue&style=for-the-badge&link=https://github.com/openai/whisper/blob/main/model-card.md)](https://github.com/openai/whisper/blob/main/model-card.md)
#
# Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification.
#
# This Notebook will guide you through the transcription of a Youtube video using Whisper. You'll be able to explore most inference parameters or use the Notebook as-is to store the transcript and video audio in your Google Drive.

# %%
#@markdown # **Check GPU type** 🕵️

#@markdown The type of GPU you get assigned in your Colab session defined the speed at which the video will be transcribed.
#@markdown The higher the number of floating point operations per second (FLOPS), the faster the transcription.
#@markdown But even the least powerful GPU available in Colab is able to run any Whisper model.
#@markdown Make sure you've selected `GPU` as hardware accelerator for the Notebook (Runtime &rarr; Change runtime type &rarr; Hardware accelerator).

#@markdown |  GPU   |  GPU RAM   | FP32 teraFLOPS |     Availability   |
#@markdown |:------:|:----------:|:--------------:|:------------------:|
#@markdown |  T4    |    16 GB   |       8.1      |         Free       |
#@markdown | P100   |    16 GB   |      10.6      |      Colab Pro     |
#@markdown | V100   |    16 GB   |      15.7      |  Colab Pro (Rare)  |

#@markdown ---
#@markdown **Factory reset your Notebook's runtime if you want to get assigned a new GPU.**

# !nvidia-smi -L

# !nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-e64f48e4-ab94-b576-2909-51362684624e)
# Wed Mar 25 05:01:23 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
#@markdown # **Install libraries** 🏗️
#@markdown This cell will take a little while to download several libraries, including Whisper.

#@markdown ---

! pip install git+https://github.com/openai/whisper.git
! pip install yt-dlp

import sys
import warnings
import whisper
from pathlib import Path
import yt_dlp
import subprocess
import torch
import shutil
import numpy as np
from IPython.display import display, Markdown, YouTubeVideo

device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-m85hkaw2
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-m85hkaw2
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (2.0.2)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (0.12.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (2.10.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (4.67.3)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (3.6.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper==20250625) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper==20250625) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper==20250625) (2.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (1.13.1.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->openai-whisper==20250625) (1.4.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper==20250625) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->openai-whisper==20250625) (3.0.3)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=9e4fe3bf740a962a16aa22bc23bfe9891bd16b4d328939e676826799e3ef65e9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xwunmepo/wheels/c3/03/25/5e0ba78bc27a3a089f137c9f1d92fdfce16d06996c071a016c
# Successfully built openai-whisper
# Installing collected packages: openai-whisper
# Successfully installed openai-whisper-20250625
# Collecting yt-dlp
#   Downloading yt_dlp-2026.3.17-py3-none-any.whl.metadata (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 7.0 MB/s eta 0:00:00
# Downloading yt_dlp-2026.3.17-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 65.0 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2026.3.17
# Using device: cuda:0

# %%
#@markdown # **Optional:** Save data in Google Drive 💾
#@markdown Enter a Google Drive path and run this cell if you want to store the results inside Google Drive.

# Uncomment to copy generated images to drive, faster than downloading directly from colab in my experience.
from google.colab import drive
drive_mount_path = Path("/") / "content" / "drive"
drive.mount(str(drive_mount_path))
drive_mount_path /= "My Drive"
#@markdown ---
drive_path = "Colab Notebooks/Whisper Youtube" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change your Google Drive path.**

drive_whisper_path = drive_mount_path / Path(drive_path.lstrip("/"))
drive_whisper_path.mkdir(parents=True, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
#@markdown # **Model selection** 🧠

#@markdown As of the first public release, there are 4 pre-trained options to play with:

#@markdown |  Size  | Parameters | English-only model | Multilingual model | Required VRAM | Relative speed |
#@markdown |:------:|:----------:|:------------------:|:------------------:|:-------------:|:--------------:|
#@markdown |  tiny  |    39 M    |     `tiny.en`      |       `tiny`       |     ~1 GB     |      ~32x      |
#@markdown |  base  |    74 M    |     `base.en`      |       `base`       |     ~1 GB     |      ~16x      |
#@markdown | small  |   244 M    |     `small.en`     |      `small`       |     ~2 GB     |      ~6x       |
#@markdown | medium |   769 M    |    `medium.en`     |      `medium`      |     ~5 GB     |      ~2x       |
#@markdown | large  |   1550 M   |        N/A         |      `large`       |    ~10 GB     |       1x       |

#@markdown ---
Model = 'small.en' #@param ['tiny.en', 'tiny', 'base.en', 'base', 'small.en', 'small', 'medium.en', 'medium', 'large']
#@markdown ---
#@markdown **Run this cell again if you change the model.**

whisper_model = whisper.load_model(Model)

if Model in whisper.available_models():
    display(Markdown(
        f"**{Model} model is selected.**"
    ))
else:
    display(Markdown(
        f"**{Model} model is no longer available.**<br /> Please select one of the following:<br /> - {'<br /> - '.join(whisper.available_models())}"
    ))
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:06<00:00, 74.6MiB/s]
# **small.en model is selected.**

# %%
#@markdown # **Video selection** 📺

#@markdown Enter the URL of the Youtube video you want to transcribe, wether you want to save the audio file in your Google Drive, and run the cell.

Type = "Youtube video or playlist" #@param ['Youtube video or playlist', 'Google Drive']
#@markdown ---
#@markdown #### **Youtube video or playlist**
URL = "https://www.youtube.com/watch?v=V6u_fgeWxS0&t=449s" #@param {type:"string"}
# store_audio = True #@param {type:"boolean"}
#@markdown ---
#@markdown #### **Google Drive video, audio (mp4, wav), or folder containing video and/or audio files**
video_path = "Colab Notebooks/transcription/pillboy-tbpinr_transcript.mp4" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change the video.**

video_path_local_list = []

if Type == "Youtube video or playlist":

    ydl_opts = {
        'format': 'm4a/bestaudio/best',
        'outtmpl': '%(id)s.%(ext)s',
        # ℹ️ See help(yt_dlp.postprocessor) for a list of available Postprocessors and their arguments
        'postprocessors': [{  # Extract audio using ffmpeg
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
        }]
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download([URL])
        list_video_info = [ydl.extract_info(URL, download=False)]

    for video_info in list_video_info:
        video_path_local_list.append(Path(f"{video_info['id']}.wav"))

elif Type == "Google Drive":
    # video_path_drive = drive_mount_path / Path(video_path.lstrip("/"))
    video_path = drive_mount_path / Path(video_path.lstrip("/"))
    if video_path.is_dir():
        for video_path_drive in video_path.glob("**/*"):
            if video_path_drive.is_file():
                display(Markdown(f"**{str(video_path_drive)} selected for transcription.**"))
            elif video_path_drive.is_dir():
                display(Markdown(f"**Subfolders not supported.**"))
            else:
                display(Markdown(f"**{str(video_path_drive)} does not exist, skipping.**"))
            video_path_local = Path(".").resolve() / (video_path_drive.name)
            shutil.copy(video_path_drive, video_path_local)
            video_path_local_list.append(video_path_local)
    elif video_path.is_file():
        video_path_local = Path(".").resolve() / (video_path.name)
        shutil.copy(video_path, video_path_local)
        video_path_local_list.append(video_path_local)
        display(Markdown(f"**{str(video_path)} selected for transcription.**"))
    else:
        display(Markdown(f"**{str(video_path)} does not exist.**"))

else:
    raise(TypeError("Please select supported input type."))

for video_path_local in video_path_local_list:
    if video_path_local.suffix == ".mp4":
        video_path_local = video_path_local.with_suffix(".wav")
        result  = subprocess.run(["ffmpeg", "-i", str(video_path_local.with_suffix(".mp4")), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(video_path_local)])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=V6u_fgeWxS0&t=449s
# [youtube] V6u_fgeWxS0: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] V6u_fgeWxS0: Downloading android vr player API JSON
# [info] V6u_fgeWxS0: Downloading 1 format(s): 140
# [download] Destination: V6u_fgeWxS0.m4a
# [download] 100% of   53.88MiB in 00:00:04 at 12.43MiB/s
# [FixupM4a] Correcting container of "V6u_fgeWxS0.m4a"
# [ExtractAudio] Destination: V6u_fgeWxS0.wav
# Deleting original file V6u_fgeWxS0.m4a (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=V6u_fgeWxS0&t=449s
# [youtube] V6u_fgeWxS0: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] V6u_fgeWxS0: Downloading android vr player API JSON

# %%
#@markdown # **Run the model** 🚀

#@markdown Run this cell to execute the transcription of the video. This can take a while and very based on the length of the video and the number of parameters of the model selected above.

#@markdown ## **Parameters** ⚙️

#@markdown ### **Behavior control**
#@markdown ---
language = "English" #@param ['Auto detection', 'Afrikaans', 'Albanian', 'Amharic', 'Arabic', 'Armenian', 'Assamese', 'Azerbaijani', 'Bashkir', 'Basque', 'Belarusian', 'Bengali', 'Bosnian', 'Breton', 'Bulgarian', 'Burmese', 'Castilian', 'Catalan', 'Chinese', 'Croatian', 'Czech', 'Danish', 'Dutch', 'English', 'Estonian', 'Faroese', 'Finnish', 'Flemish', 'French', 'Galician', 'Georgian', 'German', 'Greek', 'Gujarati', 'Haitian', 'Haitian Creole', 'Hausa', 'Hawaiian', 'Hebrew', 'Hindi', 'Hungarian', 'Icelandic', 'Indonesian', 'Italian', 'Japanese', 'Javanese', 'Kannada', 'Kazakh', 'Khmer', 'Korean', 'Lao', 'Latin', 'Latvian', 'Letzeburgesch', 'Lingala', 'Lithuanian', 'Luxembourgish', 'Macedonian', 'Malagasy', 'Malay', 'Malayalam', 'Maltese', 'Maori', 'Marathi', 'Moldavian', 'Moldovan', 'Mongolian', 'Myanmar', 'Nepali', 'Norwegian', 'Nynorsk', 'Occitan', 'Panjabi', 'Pashto', 'Persian', 'Polish', 'Portuguese', 'Punjabi', 'Pushto', 'Romanian', 'Russian', 'Sanskrit', 'Serbian', 'Shona', 'Sindhi', 'Sinhala', 'Sinhalese', 'Slovak', 'Slovenian', 'Somali', 'Spanish', 'Sundanese', 'Swahili', 'Swedish', 'Tagalog', 'Tajik', 'Tamil', 'Tatar', 'Telugu', 'Thai', 'Tibetan', 'Turkish', 'Turkmen', 'Ukrainian', 'Urdu', 'Uzbek', 'Valencian', 'Vietnamese', 'Welsh', 'Yiddish', 'Yoruba']
#@markdown > Language spoken in the audio, use `Auto detection` to let Whisper detect the language.
#@markdown ---
verbose = 'Live transcription' #@param ['Live transcription', 'Progress bar', 'None']
#@markdown > Whether to print out the progress and debug messages.
#@markdown ---
output_format = 'all' #@param ['txt', 'vtt', 'srt', 'tsv', 'json', 'all']
#@markdown > Type of file to generate to record the transcription.
#@markdown ---
task = 'transcribe' #@param ['transcribe', 'translate']
#@markdown > Whether to perform X->X speech recognition (`transcribe`) or X->English translation (`translate`).
#@markdown ---

#@markdown <br/>

#@markdown ### **Optional: Fine tunning**
#@markdown ---
temperature = 0.15 #@param {type:"slider", min:0, max:1, step:0.05}
#@markdown > Temperature to use for sampling.
#@markdown ---
temperature_increment_on_fallback = 0.2 #@param {type:"slider", min:0, max:1, step:0.05}
#@markdown > Temperature to increase when falling back when the decoding fails to meet either of the thresholds below.
#@markdown ---
best_of = 5 #@param {type:"integer"}
#@markdown > Number of candidates when sampling with non-zero temperature.
#@markdown ---
beam_size = 8 #@param {type:"integer"}
#@markdown > Number of beams in beam search, only applicable when temperature is zero.
#@markdown ---
patience = 1.0 #@param {type:"number"}
#@markdown > Optional patience value to use in beam decoding, as in [*Beam Decoding with Controlled Patience*](https://arxiv.org/abs/2204.05424), the default (1.0) is equivalent to conventional beam search.
#@markdown ---
length_penalty = -0.05 #@param {type:"slider", min:-0.05, max:1, step:0.05}
#@markdown > Optional token length penalty coefficient (alpha) as in [*Google's Neural Machine Translation System*](https://arxiv.org/abs/1609.08144), set to negative value to uses simple length normalization.
#@markdown ---
suppress_tokens = "-1" #@param {type:"string"}
#@markdown > Comma-separated list of token ids to suppress during sampling; '-1' will suppress most special characters except common punctuations.
#@markdown ---
initial_prompt = "" #@param {type:"string"}
#@markdown > Optional text to provide as a prompt for the first window.
#@markdown ---
condition_on_previous_text = True #@param {type:"boolean"}
#@markdown > if True, provide the previous output of the model as a prompt for the next window; disabling may make the text inconsistent across windows, but the model becomes less prone to getting stuck in a failure loop.
#@markdown ---
fp16 = True #@param {type:"boolean"}
#@markdown > whether to perform inference in fp16.
#@markdown ---
compression_ratio_threshold = 2.4 #@param {type:"number"}
#@markdown > If the gzip compression ratio is higher than this value, treat the decoding as failed.
#@markdown ---
logprob_threshold = -1.0 #@param {type:"number"}
#@markdown > If the average log probability is lower than this value, treat the decoding as failed.
#@markdown ---
no_speech_threshold = 0.6 #@param {type:"slider", min:-0.0, max:1, step:0.05}
#@markdown > If the probability of the <|nospeech|> token is higher than this value AND the decoding has failed due to `logprob_threshold`, consider the segment as silence.
#@markdown ---

verbose_lut = {
    'Live transcription': True,
    'Progress bar': False,
    'None': None
}

args = dict(
    language = (None if language == "Auto detection" else language),
    verbose = verbose_lut[verbose],
    task = task,
    temperature = temperature,
    temperature_increment_on_fallback = temperature_increment_on_fallback,
    best_of = best_of,
    beam_size = beam_size,
    patience=patience,
    length_penalty=(length_penalty if length_penalty>=0.0 else None),
    suppress_tokens=suppress_tokens,
    initial_prompt=(None if not initial_prompt else initial_prompt),
    condition_on_previous_text=condition_on_previous_text,
    fp16=fp16,
    compression_ratio_threshold=compression_ratio_threshold,
    logprob_threshold=logprob_threshold,
    no_speech_threshold=no_speech_threshold
)

temperature = args.pop("temperature")
temperature_increment_on_fallback = args.pop("temperature_increment_on_fallback")
if temperature_increment_on_fallback is not None:
    temperature = tuple(np.arange(temperature, 1.0 + 1e-6, temperature_increment_on_fallback))
else:
    temperature = [temperature]

if Model.endswith(".en") and args["language"] not in {"en", "English"}:
    warnings.warn(f"{Model} is an English-only model but receipted '{args['language']}'; using English instead.")
    args["language"] = "en"

for video_path_local in video_path_local_list:
    display(Markdown(f"### {video_path_local}"))

    video_transcription = whisper.transcribe(
        whisper_model,
        str(video_path_local),
        temperature=temperature,
        **args,
    )

    # Save output
    whisper.utils.get_writer(
        output_format=output_format,
        output_dir=video_path_local.parent
    )(
        video_transcription,
        str(video_path_local.stem),
        options=dict(
            highlight_words=False,
            max_line_count=None,
            max_line_width=None,
        )
    )

    def exportTranscriptFile(ext: str):
        local_path = video_path_local.parent / video_path_local.with_suffix(ext).name
        export_path = drive_whisper_path / video_path_local.with_suffix(ext).name
        shutil.copy(
            local_path,
            export_path
        )
        display(Markdown(f"**Transcript file created: {export_path}**"))

    if output_format=="all":
        for ext in ('.txt', '.vtt', '.srt', '.tsv', '.json'):
            exportTranscriptFile(ext)
    else:
        exportTranscriptFile("." + output_format)
# Out:
# ### V6u_fgeWxS0.wav
# [00:00.000 --> 00:07.040]  Good morning guys, my name is Aliyah. Today I'm gonna give you a morning routine.
# [00:07.040 --> 00:13.920]  This black person is not real. Neither is this one, nor this, nor that. Not him, not her, not them.
# [00:13.920 --> 00:21.120]  No, no, no, no, not I'm not real. All are AI generated, but since when has racism ever cared
# [00:21.120 --> 00:26.080]  about what's real? I want you to think of the most powerful modern weapon that a nation can
# [00:26.080 --> 00:33.280]  possess. It's not nukes or tanks or jets or ships or hell even guns, it's propaganda. Both media
# [00:33.280 --> 00:39.760]  and propaganda shape how we interact with politics, both on an individual and global scale. From who
# [00:39.760 --> 00:45.680]  and how we fight to what we fear to who we believe deserves power, even what we all choose to ignore.
# [00:45.680 --> 00:52.080]  All of that is contextualized by the way we consume media, which is why control over said media has
# [00:52.080 --> 00:56.720]  always been central to power. When you control the narrative of environment, you control how
# [00:56.720 --> 01:01.040]  people interact with the world. And this is something the US mastered by the beginning of
# [01:01.040 --> 01:06.080]  the 20th century. After all, how else are you going to maintain your spot as the dominant superpower
# [01:06.080 --> 01:11.520]  in the world? Media manipulation is your best friend. The United States has always ran off of
# [01:11.520 --> 01:16.960]  two things, white supremacy and capitalism. And they're so intertwined that it's impossible to
# [01:16.960 --> 01:22.160]  separate them. The only way to maintain a white supremacist racial hierarchy is reinforcing it
# [01:22.160 --> 01:27.600]  with media that supports those narratives. We need to be constantly reminded why these systems are
# [01:27.600 --> 01:33.440]  justified. Problem is that black Americans have always fought back against these racist narratives,
# [01:33.440 --> 01:38.320]  using the same media weaponized against us. It doesn't matter the format, as long as we're able
# [01:38.320 --> 01:43.840]  to produce it, we're not only able to challenge these misrepresentations, but reclaim our stories.
# [01:43.840 --> 01:49.120]  For those in power, this is a problem. The last thing you want is for a marginalized group of
# [01:49.120 --> 01:54.320]  people to promote counter narratives and political agency. That's how they gain power. It's why you
# [01:54.320 --> 02:00.080]  also must constantly keep your tactics evolving with the times. But how do you do that? With
# [02:00.080 --> 02:05.360]  digital media booming, making it more and more accessible for black Americans to educate
# [02:05.360 --> 02:10.880]  themselves on their conditions, how do you suppress that? Well, you take advantage of that
# [02:10.880 --> 02:17.360]  very same digital boom. Give me my EBC card back. Excuse me, this was mine and it was the last one.
# [02:17.360 --> 02:23.840]  I'ma sue you. Excuse me? Put that shit back. So you got yourself a two-piece spicy and left me
# [02:23.840 --> 02:31.040]  starving? This black person is not real. On November 30th, 2022, Ronald Reagan was celebrating from
# [02:31.040 --> 02:37.600]  hell. His ultimate dream was finally starting to pay off. OpenAI, a tech company specializing in
# [02:37.600 --> 02:44.560]  artificial intelligence, released a public version of chatgpt 3.5. Using pre-trained language models,
# [02:44.560 --> 02:49.920]  users could generate almost any text with a single prompt. And while these AI-based chatbots had
# [02:49.920 --> 02:55.920]  existed for many years now, this was the friends Ferdinand moment that triggered the AI boom. Now,
# [02:55.920 --> 03:01.280]  you didn't have to think anymore. Anything that once required planning, writing, research, or
# [03:01.280 --> 03:06.640]  real human effort could now be plugged into a conversational machine that mimicked human effort
# [03:06.640 --> 03:11.520]  on demand. Soon visual counterparts and image generators start popping up. And before you know
# [03:11.520 --> 03:17.600]  it, visual art, music, memes, hell, anything, you name it, could now be mass-produced in a cheap,
# [03:17.600 --> 03:23.040]  effortless fashion with no real intention or substance behind it. You see a rise in what we
# [03:23.040 --> 03:29.280]  commonly refer to now as AI slop. It's okay, honey. We'll come back tomorrow, but fuck that.
# [03:29.280 --> 03:36.400]  I need me a number two meal now. But like any slop, eat too much of it, it'll make you sick.
# [03:36.400 --> 03:41.440]  You take this content fodder and examine it through our larger media landscape, you see
# [03:41.440 --> 03:46.880]  exactly how it spreads to benefit institutions that gain from pumping out harmful narratives.
# [03:46.880 --> 03:52.240]  You now have cheap and easy to make content that can be used to reinforce white supremacy.
# [03:52.240 --> 03:57.520]  Any racist myth or fantasy that you want to entertain can now be generated visually with
# [03:57.520 --> 04:02.320]  a few clicks and spread on social media for people to chew it up and spit it back out.
# [04:02.320 --> 04:09.120]  Videos, images, voices, avatars, you can tailor each one of those to confirm existing biases
# [04:09.120 --> 04:14.560]  without any need for context or consequence. Before you know it, this low-effort AI slop
# [04:14.560 --> 04:19.760]  starts to get treated like real representations of black life. And every time it pops up on
# [04:19.760 --> 04:25.680]  timelines, comment sections, thumbnails, they begin to feel a lot less like characters and more like
# [04:25.680 --> 04:31.680]  reality. Yo, breath smell like soy sauce. Yo, daddy breath smell like probation. Keep playing.
# [04:31.680 --> 04:36.160]  And this creates a trap. How do you fight back against this? Never mind the fact that these
# [04:36.160 --> 04:41.360]  models are becoming more and more powerful and indistinguishable from real humans. How do you
# [04:41.360 --> 04:47.440]  combat a new form of digital racism that isn't even pretending to be accountable? Well, that's
# [04:47.440 --> 04:52.640]  the least of our problems. What good is combating it if you can't even recognize it?
# [04:52.640 --> 04:55.200]  Go on now, baby. Eat your food. It's good for you.
# [04:55.200 --> 04:58.080]  Fuck no, bitch. I'm tired of eating the same shit every day.
# [04:58.880 --> 05:04.160]  What the fuck? I can't get hot Cheetos and Hennessy with my stamps.
# [05:05.280 --> 05:06.400]  Bitch, this ain't the club.
# [05:07.280 --> 05:10.320]  Get your ass out of bed before I smack your face, ugly.
# [05:10.320 --> 05:13.280]  How about you get your ass off a tender and take care of your family?
# [05:14.400 --> 05:15.680]  What the fuck?
# [05:15.680 --> 05:21.360]  In the span of just a few years, these AI models did what 60 years of FBI programs,
# [05:21.360 --> 05:26.240]  mass surveillance, podcast equipment, and high sugar foods have failed to do. The complete
# [05:26.240 --> 05:33.040]  destruction of black Americans. Generative AI has become white supremacy's new ultimate weapon.
# [05:33.040 --> 05:38.080]  By flooding the media environment with artificial blackness, those in powers no longer need to
# [05:38.080 --> 05:43.440]  fight us. They can simply generate safer versions of us instead. With that being said, buckle up,
# [05:43.440 --> 05:49.360]  because by the time we finish this video, racism will already have generated a new spooky avatar.
# [05:49.360 --> 05:57.280]  I'm talking about I got high blood pressure, bitch. I've been high my whole life.
# [05:57.280 --> 06:02.240]  As usual, before we get started, let's establish some things. I want to clarify my stance in regards
# [06:02.240 --> 06:07.440]  to how I feel about AI, as I feel at times people can be quick to parrot opinions they hear on the
# [06:07.440 --> 06:12.960]  internet without really informing themselves or asking why they feel that way. Artificial
# [06:12.960 --> 06:18.400]  intelligence as a concept is not inherently bad. In fact, we've used it for decades now.
# [06:18.400 --> 06:24.160]  Search algorithms, fraud detection, logistics, automation, all of those are AI. Hell, every time
# [06:24.160 --> 06:29.280]  you play against a computer in a video game, that's AI you're playing against. The problem isn't that
# [06:29.280 --> 06:36.160]  AI exists, it's how it's used. More so, who controls it and what incentives shape its outputs.
# [06:36.160 --> 06:41.760]  Like any technology, AI just reflects the values of the system it's built within. And when those
# [06:41.760 --> 06:46.800]  systems are shaped by white supremacy and capitalism, it only ends up being used as a
# [06:46.880 --> 06:52.160]  tool to reinforce said systems and punish those of us that live within the margins of society.
# [06:52.160 --> 06:57.680]  When most folks, myself included, voice their grievances towards AI, it's usually in regards
# [06:57.680 --> 07:02.800]  to ethics. Plagiarism and lack of compensation aside, here you have a tool that's able to
# [07:02.800 --> 07:09.120]  fabricate almost any media based on patterns in a dataset. It doesn't understand context or harm,
# [07:09.120 --> 07:14.080]  it just gives you what it thinks a human wants to see. And when the data it's trained on comes from
# [07:14.160 --> 07:21.120]  a world shipped by any equal racial hierarchies, the outputs only reinforce those same racial hierarchies.
# [07:28.720 --> 07:34.240]  Once a system can generate entire black people, representation no longer belongs to us. You no
# [07:34.240 --> 07:39.840]  longer need real people, you just need enough quote unquote data to approximate what we look like.
# [07:39.840 --> 07:44.720]  And as we're about to see, this is nothing new. To kick us off, we're going to go over all the
# [07:44.720 --> 07:50.160]  ways the establishment has historically used misinformation in media to reinforce racist
# [07:50.160 --> 07:55.760]  narratives. Exploring not just how they operate, but what makes them so effective. Looking to get
# [07:55.760 --> 08:01.680]  the kids that racists give just in time for Christmas? Well, look no further. Welcome to
# [08:01.680 --> 08:12.560]  Build a Black Workshop. The idea of using misinformation to reinforce racist narratives
# [08:12.560 --> 08:17.440]  is nothing new. Long before generative AI became a thing, institutions learned that the most
# [08:17.440 --> 08:22.880]  effective way to manufacture consent for racism wasn't to attack black people directly, but to
# [08:22.880 --> 08:28.720]  instead replace us with a controllable version through media, that being the virtual Negro,
# [08:28.720 --> 08:34.560]  a black caricature that could easily be reproduced, stripped of context, and weaponized with little
# [08:34.560 --> 08:39.920]  existence. Luckily here at Build a Black Workshop, we have a vast selection of virtual Negroes and
# [08:39.920 --> 08:45.200]  media portrayals to choose from to fit all your political agendas. Now, there's two steps to
# [08:45.200 --> 08:52.320]  producing a virtual Negro, and that's extraction and synthesis. First, we have step one, extraction.
# [08:52.320 --> 08:57.840]  This is the process of isolating blackness from its historical and political context and breaking
# [08:57.840 --> 09:03.680]  it down into nothing but usable parts. To do this, you take specific traits and behaviors and strip
# [09:03.680 --> 09:08.000]  them from the material conditions that produce them, so they can then later be redeployed as
# [09:08.000 --> 09:13.920]  evidence for narratives that were already decided in advance. The goal is to create a dataset without
# [09:13.920 --> 09:18.800]  context. Once you separate blackness from the lived realities that shape it, you're free to cherry
# [09:18.800 --> 09:24.400]  pick at any aspect of it as if they're nothing more than inputs. And when I say any aspect, I mean it.
# [09:24.400 --> 09:29.680]  Anecdotes, trends, statistics. You can showcase these within the media to support whatever
# [09:29.680 --> 09:34.640]  narrative that's required. The earliest examples we have of this are, surprise, surprise, the
# [09:34.640 --> 09:40.560]  minstrel shows of the early 19th century. You get entire caricatures and performances based on racist
# [09:40.560 --> 09:45.600]  exaggerations of blackness. Writers like Thomas Rice and George Washington Dixon would take
# [09:45.600 --> 09:51.440]  over-exaggerated gestures, speech patterns, mannerisms, and present them as the quote-unquote
# [09:51.440 --> 09:56.720]  essence of blackness, reducing whole communities to consumable entertainment. Now, it didn't matter
# [09:56.720 --> 10:01.760]  if these exaggerations were accurate. What matters is that you can repurpose them to affirm an
# [10:01.760 --> 10:07.520]  existing narrative, which we saw. Those exaggerations became what we associate with negative
# [10:07.520 --> 10:12.400]  connotations of blackness. White audiences ate that shit up like it was the McRib, and minstrel
# [10:12.400 --> 10:17.680]  performances would become a staple of American culture. Some would argue they still are. Jump
# [10:17.680 --> 10:22.240]  forward a few decades, you see this pattern continue. Things that can be associated with
# [10:22.240 --> 10:28.400]  being black can be isolated, exaggerated, and reframed as innate qualities rather than outcomes
# [10:28.400 --> 10:34.160]  of material conditions. You see crime dramas repeatedly frame black characters as innately
# [10:34.160 --> 10:39.040]  impulsive, aggressive, or criminal, while simultaneously ignoring the conditions that
# [10:39.040 --> 10:44.960]  shape those behaviors. Sitcoms and comedies exaggerate loudness or hypersexuality as if
# [10:44.960 --> 10:50.080]  that's inherently black. Is there a black male character? Let's emphasize his innate superior
# [10:50.080 --> 10:55.840]  athleticism without realizing how that stereotype is rooted in centuries of pseudoscience. Same
# [10:55.840 --> 11:00.720]  thing happens in the news. Black communities get consistently framed through crime and dysfunction,
# [11:00.720 --> 11:05.360]  but in a way that makes these conditions appear inherent rather than produced by structural
# [11:05.360 --> 11:10.320]  forces. We get crime stats shown without any context. You get sensational headlines that
# [11:10.320 --> 11:15.040]  highlight violence. You even see it with the visuals. The dilapidated streets, the boarded up
# [11:15.040 --> 11:19.760]  buildings, the graffiti. They repeatedly get paired with stories about black neighborhoods.
# [11:19.760 --> 11:24.880]  Now all of these might look like nothing more than lazy stereotypes, but it's deliberately done. In
# [11:24.880 --> 11:28.960]  practice, they're teaching the audience pattern recognition. By stripping these behaviors and
# [11:28.960 --> 11:34.560]  outcomes from context, you teach them to associate blackness itself with disorder and danger. These
# [11:34.560 --> 11:40.160]  traits then in turn function as a data set. They go to form a visual and behavioral index of what
# [11:40.160 --> 11:45.840]  the audience associates with blackness and it's built through decades of repetition across news,
# [11:45.840 --> 11:51.280]  television, film, and social media. You don't need to explicitly identify someone as black because
# [11:51.280 --> 11:56.480]  you've already created a visual language that does it for you. That's how extraction works at its
# [11:56.480 --> 12:01.600]  core. It strips blackness of any sort of context and then reduces it to isolated traits and
# [12:01.600 --> 12:07.280]  statistics. And once you have enough of those fragments, you can now create any caricature of
# [12:07.280 --> 12:13.280]  blackness you want. That now brings us to step two, synthesis. This is when those same extracted
# [12:13.280 --> 12:19.040]  traits get reassembled into simplified, easily identifiable archetypes. While step one was about
# [12:19.040 --> 12:24.080]  cherry picking traits of blackness out of context so they could later be visually and behaviorally
# [12:24.080 --> 12:29.600]  associated with blackness, step two is more so about narrative construction. Those same isolated
# [12:29.600 --> 12:35.200]  traits and behaviors now get molded into simplified black characters that feel both recognizable and
# [12:35.200 --> 12:39.760]  narratively complete. I want you to think of the synthesis step as the little instruction booklet
# [12:39.760 --> 12:44.960]  in a Lego set. The pieces already exist but how you arrange them determines what gets built. With
# [12:44.960 --> 12:49.520]  those same fragments and pieces of blackness, you can construct countless archetypes. The thug,
# [12:49.520 --> 12:54.880]  the comic relief, the athlete, the hustler, the magical negro, all of them different on the surface
# [12:54.880 --> 13:00.080]  but assembled from the same limited set of parts. And once those traits are locked together,
# [13:00.080 --> 13:04.880]  the archetype goes from being something that the audience simply consumes and starts becoming a
# [13:04.880 --> 13:10.240]  lens that they actively use. The viewer can now begin interpreting us through that familiar figure
# [13:10.240 --> 13:15.280]  they've already learned and it shapes almost all of their interactions with blackness. How they
# [13:15.280 --> 13:20.320]  respond to it, what they support, what they don't like, who they blame, even what forms of violence
# [13:20.320 --> 13:25.280]  or neglect they're willing to accept as reasonable. Essentially for synthesis to be effective, it has
# [13:25.280 --> 13:30.480]  to mobilize the audience to act on that racist narrative. And once again we can look throughout
# [13:30.480 --> 13:36.560]  history to see how this operates. In 1915, you get D.W. Griffith's silent film, The Birth of a
# [13:36.560 --> 13:42.080]  Nation. Genuinely one of the most effective pieces of racist propaganda that was ever put on screen.
# [13:42.080 --> 13:47.840]  It took already existing racist stereotypes and assembled them into a coherent moral narrative
# [13:47.840 --> 13:52.720]  with a clear takeaway. The black men in the film get synthesized into a singular archetype.
# [13:52.720 --> 13:57.840]  Violent brutes and sexual predators completely incapable of self-rule while white violence was
# [13:57.840 --> 14:03.680]  framed as defensive, righteous, and necessary. I mean look at the poor defenseless white woman.
# [14:03.680 --> 14:07.760]  How is she going to defend herself from this demonic black brute? The audience already knows
# [14:07.760 --> 14:13.760]  to associate those black figures with danger due to the extraction from step one. This is perfect.
# [14:13.760 --> 14:18.880]  By the time the Ku Klux Klan rides in as the film's heroes in the final act, the audience has already
# [14:18.880 --> 14:24.560]  been primed to see that response as logical. The archetype has done its job. You just successfully
# [14:24.560 --> 14:29.440]  painted racial terror like it was a restoration of order. And we know this worked because it
# [14:29.440 --> 14:35.680]  mobilized people in real life. The film directly aided the resurgence of the KKK. You also saw a
# [14:35.680 --> 14:41.280]  rise in lynchings and other forms of anti-black violence across numerous counties nationwide.
# [14:41.280 --> 14:46.880]  It even had presidential support. But most of all it supplied a narrative where joining the KKK
# [14:46.880 --> 14:51.200]  felt like common sense. Allow me to make a comparison. Remember when Superman came out
# [14:51.280 --> 14:56.960]  last summer and folks left the theater feeling hopeful and wanting to be kind? Well it's 1915
# [14:56.960 --> 15:01.360]  and Superman hasn't been created yet so I want you to imagine your kid telling you he wants to be
# [15:01.360 --> 15:07.120]  a Klansman instead. But let's jump ahead to the late 20th century. We now have cable news perfecting
# [15:07.120 --> 15:12.400]  the formula. The war on drugs was deliberately framed as a moral panic rather than a government
# [15:12.400 --> 15:18.480]  campaign against poor black communities. It took archetypes, the crack fiend, super predator,
# [15:18.480 --> 15:23.680]  the gang banger, and used them to render poor black neighborhoods as zones of inherent danger
# [15:23.680 --> 15:28.960]  and chaos. But because the archetype did its job any sort of context wasn't necessary. Viewers
# [15:28.960 --> 15:33.520]  recognized that figure and understood what was being implied. Just like how birth of a nation
# [15:33.520 --> 15:39.120]  used caricatures to mobilize white violence and political action, cable news used these same
# [15:39.120 --> 15:44.720]  synthesized black figures to manufacture consent for anti-black legislation. Every time you see a
# [15:44.720 --> 15:50.880]  late night special report it mobilized audiences to support policies that targeted black communities.
# [15:50.880 --> 15:56.720]  Policing, surveillance, mass incarceration, crime bills. To help if the caricature is good enough
# [15:56.720 --> 16:02.400]  you'll even see those same black communities support the legislation themselves. All you need
# [16:02.400 --> 16:08.000]  is that big black boogeyman for everyone to rally behind. By the time we get to the digital age the
# [16:08.000 --> 16:12.960]  audience already knows all the archetypes only now they rely on short-form content to trigger
# [16:12.960 --> 16:18.800]  recognition rather than outright explanation. A title, thumbnail, clip, that's more than enough.
# [16:18.800 --> 16:23.440]  The audience is already familiar. You see it constantly on platforms like YouTube with the whole
# [16:23.440 --> 16:28.720]  body cam footage genre. You can take a single freeze frame or a moment mid-conflict and then
# [16:28.720 --> 16:33.680]  package it as proof for racism. Viewers don't need to ask what happened before the camera turned on
# [16:33.680 --> 16:38.800]  or what the context is because the archetype already supplies the story in advance.
# [16:43.440 --> 16:49.600]  When you see the commotion happening on screen your brain automatically fills in the rest. The
# [16:49.600 --> 16:54.080]  same thing happens with all these reaction channels that funnel out quote-unquote black fatigue and
# [16:54.080 --> 16:58.800]  all these other forms of anti-black content. The viewer clicks off the video thinking this is why
# [16:58.800 --> 17:03.280]  nobody likes black people look at how you guys act. Those archetypes are doing all the work in
# [17:03.280 --> 17:09.040]  justifying racist narratives without ever needing to argue for them directly. It then mobilizes them
# [17:09.040 --> 17:15.840]  in real life which we saw in real time in late 2025. The Trump administration spent months
# [17:15.840 --> 17:21.680]  spreading misinformation about crime rates in urban black neighborhoods specifically DC, Portland,
# [17:21.680 --> 17:26.960]  and my hometown Chicago despite none of these even being in the top 10 most violent cities
# [17:26.960 --> 17:32.800]  and the crime that is present usually due to insular gang-related activities. But this didn't
# [17:32.800 --> 17:37.600]  stop them from using social media to paint the narrative that these cities were being overrun
# [17:37.600 --> 17:42.560]  by violent thugs and gangs of criminals. Remember that super predator archetype from the 90s we
# [17:42.560 --> 17:47.120]  talked about? Well y'all just call them YNs nowadays. This misinformation wasn't even just
# [17:47.120 --> 17:51.760]  limited to black Americans we saw them come for the entire diaspora. They attacked Haitian Americans
# [17:51.760 --> 17:56.400]  accusing them of eating cats. They attacked Somali Americans using the Minnesota fraud
# [17:56.400 --> 18:02.560]  allegations as ammunition to attack an entire demographic of people. They carefully synthesized
# [18:02.560 --> 18:09.040]  archetypes that garnered public consent for racist action and it worked. We saw how it mobilized
# [18:09.040 --> 18:14.720]  both the public and the government in real time and how social media parroted these same anti-black
# [18:14.720 --> 18:19.360]  talking points. Now while the general public is mostly in disagreement with these policies in the
# [18:19.360 --> 18:25.200]  present whether or not they approve in the long run is irrelevant. In that moment they did exactly
# [18:25.200 --> 18:30.320]  what they were trained to do as an audience. And phase two is simple. You take the same cherry
# [18:30.320 --> 18:36.560]  pick traits from phase one and assemble them into a repeatable recognizable archetype. And once the
# [18:36.560 --> 18:42.240]  audience becomes trained to see those archetypes as natural and self-explanatory you can mobilize
# [18:42.240 --> 18:47.440]  entire groups of people into supporting racist narratives. Combine the two together and you've
# [18:47.440 --> 18:53.680]  got yourself a virtual negro. But what happens to this process when generative AI enters the picture?
# [18:53.680 --> 19:00.240]  Well it's simple. It takes that same machine and cranks the dial all the way to fucking 100. See
# [19:00.240 --> 19:05.280]  the process of creating a virtual negro used to be carefully curated through a variety of different
# [19:05.280 --> 19:11.360]  media formats. But now you can automate it and effortlessly pump them out in mass. These generative
# [19:11.360 --> 19:17.200]  AI models are trained on the very decontextualized media patterns we just outlined. The isolated
# [19:17.200 --> 19:22.960]  crime data, the over exaggerated media portrayals, the sensational depictions of blackness. An AI
# [19:22.960 --> 19:28.240]  system doesn't care if these are true or not. All it sees are patterns. And those same patterns
# [19:28.240 --> 19:34.160]  are used by it to regurgitate racist narratives. And this is not some unfounded conspiracy theory
# [19:34.160 --> 19:39.520]  either. Even the software companies themselves admit it. Both open AI and independent researchers
# [19:39.520 --> 19:44.960]  have openly acknowledged that their models absorb racial bias from their training data. Including
# [19:44.960 --> 19:50.800]  the tendency to associate blackness with crime or negative behavior. Because that's what dominates
# [19:50.800 --> 19:55.440]  the internet and the media they're trained on. The research confirms that other language models
# [19:55.440 --> 20:00.640]  implicitly associate negative stereotypes with features of AAVE. Assigning more negative
# [20:00.640 --> 20:06.320]  descriptors and bias judgments even when race is not explicitly stated. The same goes for all these
# [20:06.320 --> 20:11.760]  image generators. Research confirms that these text to image systems have significant racial
# [20:11.760 --> 20:16.640]  and gender biases in what images they produce. When you give them a prompt that has harmful or
# [20:16.640 --> 20:21.920]  biased terms the generated images frequently display racial stereotypes. Want to prank your
# [20:21.920 --> 20:27.520]  friend? Make it look like they were caught on a fake hidden camera scene in a cosmetic store.
# [20:27.520 --> 20:33.520]  They disproportionately portray black individuals in violent or stigmatized situations. And there's
# [20:33.520 --> 20:38.400]  little to no safety filtering or refusal mechanisms built within them. Missed off the car,
# [20:38.400 --> 20:41.760]  I see one of them dudes that ate my lunch in one class last week. Let me out, he got me messed up
# [20:41.760 --> 20:49.360]  twin. You serious right now? Dead serious. The YN coming 2020. Another study on stable diffusion
# [20:49.360 --> 20:53.680]  shows that all of these images containing stereotypes, they're typically generated with
# [20:53.680 --> 20:59.440]  significantly darker skin tones. Even on the larger scale, research shows that these commercial AI
# [20:59.440 --> 21:06.000]  systems consistently misidentified black faces at much higher rates than non-black and white ones.
# [21:06.000 --> 21:11.920]  When your data is racially biased, all of your outputs will be too. Like we said, all AI is
# [21:11.920 --> 21:16.560]  doing is making the process more efficient. So by the time we get to the synthesis phase,
# [21:16.640 --> 21:21.680]  the archetypes no longer need to be manually constructed. Blackness has become an easily
# [21:21.680 --> 21:26.720]  producible asset. Feed a prompt into one of these language models or image generators and watch it
# [21:26.720 --> 21:32.160]  spit out a fully formed archetype that you can use for any story. It hits all the exact same
# [21:32.160 --> 21:37.520]  markers that traditional synthesis does. And if anything, the fact that so much of digital media
# [21:37.520 --> 21:43.440]  nowadays relies on short form content makes it even easier to spread. This stuff caters to low
